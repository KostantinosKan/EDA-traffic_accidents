# %% [markdown]
# <h1><center><font color = "red">Data Preprocessing</font></h1>

# %% [markdown]
# <h3><font color = "green">Load Necessary Libraries</font></h3>

# %%
# important libraries
import pandas as pd
import numpy as np
import warnings
import os

# display all features
pd.set_option("display.max_columns", None)

# filter warnings
warnings.filterwarnings(action="ignore")

# %% [markdown]
# <h3><font color = "green">Load and Display Dataset</font></h3>

# %%
DATASETS_file = "../cleaning"
csv_file = "accidents_df_cleaned.csv"

csv_file_path = os.path.join(DATASETS_file, csv_file)
accidents_df = pd.read_csv(filepath_or_buffer=csv_file_path)

print(f"accidents_df shape:\t{accidents_df.shape}")
accidents_df.head()
# Out:
# accidents_df shape:	(1370980, 44)
#           ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-2716600         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2716605         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
# 2  A-2716606         2  2016-02-08 08:16:57  2016-02-08 14:16:57  39.063240
# 3  A-2716607         2  2016-02-08 08:16:57  2016-02-08 14:16:57  39.067080
# 4  A-2716608         2  2016-02-08 08:15:41  2016-02-08 14:15:41  39.775650
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)           Street Side  \
# 0 -83.092860  40.112060 -83.031870         3.230      Outerbelt E    R
# 1 -84.492792  39.170476 -84.501798         0.500           I-75 S    R
# 2 -84.032430  39.067310 -84.058510         1.427   State Route 32    R
# 3 -84.058550  39.063020 -84.032540         1.423   State Route 32    R
# 4 -84.186030  39.772750 -84.188050         0.227           I-75 S    R
#
#            City      County State Zipcode    Timezone Airport_Code  \
# 0        Dublin    Franklin    OH   43017  US/Eastern         KOSU
# 1    Cincinnati    Hamilton    OH   45217  US/Eastern         KLUK
# 2  Williamsburg    Clermont    OH   45176  US/Eastern         KI69
# 3       Batavia    Clermont    OH   45103  US/Eastern         KI69
# 4        Dayton  Montgomery    OH   45404  US/Eastern         KFFO
#
#      Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 0  2016-02-08 00:53:00            42.1           36.1         58.0
# 1  2016-02-08 07:53:00            37.0           29.8         93.0
# 2  2016-02-08 08:16:00            35.6           29.2        100.0
# 3  2016-02-08 08:16:00            35.6           29.2        100.0
# 4  2016-02-08 08:18:00            33.8            NaN        100.0
#
#    Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 0         29.76            10.0             SW             10.4
# 1         29.69            10.0            WSW             10.4
# 2         29.66            10.0            WSW              8.1
# 3         29.66            10.0            WSW              8.1
# 4         29.63             3.0             SW              2.3
#
#    Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  Give_Way  \
# 0               0.00        Light Rain    False  False     False     False
# 1               0.01        Light Rain    False  False     False     False
# 2                NaN          Overcast    False  False     False     False
# 3                NaN          Overcast    False  False     False     False
# 4                NaN     Mostly Cloudy    False  False     False     False
#
#    Junction  No_Exit  Railway  Roundabout  Station   Stop  Traffic_Calming  \
# 0     False    False    False       False    False  False            False
# 1     False    False    False       False    False  False            False
# 2     False    False    False       False    False  False            False
# 3     False    False    False       False    False  False            False
# 4     False    False    False       False    False  False            False
#
#    Traffic_Signal  Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False         False          Night          Night
# 1           False         False            Day            Day
# 2            True         False            Day            Day
# 3           False         False            Day            Day
# 4           False         False            Day            Day
#
#   Nautical_Twilight Astronomical_Twilight
# 0             Night                 Night
# 1               Day                   Day
# 2               Day                   Day
# 3               Day                   Day
# 4               Day                   Day

# %% [markdown]
# <h3><font color = "green">General Informations</font></h3>

# %%
# Check for data types 
accidents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370980 entries, 0 to 1370979
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   ID                     1370980 non-null  object
#  1   Severity               1370980 non-null  int64
#  2   Start_Time             1370980 non-null  object
#  3   End_Time               1370980 non-null  object
#  4   Start_Lat              1370980 non-null  float64
#  5   Start_Lng              1370980 non-null  float64
#  6   End_Lat                1370980 non-null  float64
#  7   End_Lng                1370980 non-null  float64
#  8   Distance(mi)           1370980 non-null  float64
#  9   Street                 1370980 non-null  object
#  10  Side                   1370980 non-null  object
#  11  City                   1370980 non-null  object
#  12  County                 1370980 non-null  object
#  13  State                  1370980 non-null  object
#  14  Zipcode                1370980 non-null  object
#  15  Timezone               1370980 non-null  object
#  16  Airport_Code           1370980 non-null  object
#  17  Weather_Timestamp      1370980 non-null  object
#  18  Temperature(F)         1370980 non-null  float64
#  19  Wind_Chill(F)          1058853 non-null  float64
#  20  Humidity(%)            1370980 non-null  float64
#  21  Pressure(in)           1370980 non-null  float64
#  22  Visibility(mi)         1370980 non-null  float64
#  23  Wind_Direction         1370980 non-null  object
#  24  Wind_Speed(mph)        1370980 non-null  float64
#  25  Precipitation(in)      976579 non-null   float64
#  26  Weather_Condition      1370980 non-null  object
#  27  Amenity                1370980 non-null  bool
#  28  Bump                   1370980 non-null  bool
#  29  Crossing               1370980 non-null  bool
#  30  Give_Way               1370980 non-null  bool
#  31  Junction               1370980 non-null  bool
#  32  No_Exit                1370980 non-null  bool
#  33  Railway                1370980 non-null  bool
#  34  Roundabout             1370980 non-null  bool
#  35  Station                1370980 non-null  bool
#  36  Stop                   1370980 non-null  bool
#  37  Traffic_Calming        1370980 non-null  bool
#  38  Traffic_Signal         1370980 non-null  bool
#  39  Turning_Loop           1370980 non-null  bool
#  40  Sunrise_Sunset         1370980 non-null  object
#  41  Civil_Twilight         1370980 non-null  object
#  42  Nautical_Twilight      1370980 non-null  object
#  43  Astronomical_Twilight  1370980 non-null  object
# dtypes: bool(13), float64(12), int64(1), object(18)
# memory usage: 341.2+ MB

# %%
# Check statistics
accidents_df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  1.370980e+06  1.370980e+06  1.370980e+06  1.370980e+06  1.370980e+06
# mean   2.223431e+00  3.687072e+01 -9.858667e+01  3.687078e+01 -9.858647e+01
# std    5.951861e-01  5.202776e+00  1.846727e+01  5.202751e+00  1.846714e+01
# min    1.000000e+00  2.457022e+01 -1.244976e+02  2.457011e+01 -1.244978e+02
# 25%    2.000000e+00  3.383234e+01 -1.182171e+02  3.383233e+01 -1.182171e+02
# 50%    2.000000e+00  3.732941e+01 -9.409633e+01  3.732943e+01 -9.409387e+01
# 75%    2.000000e+00  4.073800e+01 -8.092084e+01  4.073834e+01 -8.092127e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  1.370980e+06    1.370980e+06   1.058853e+06  1.370980e+06
# mean   5.744937e-01    5.979587e+01   5.515266e+01  6.420014e+01
# std    1.612182e+00    1.824638e+01   2.110355e+01  2.322987e+01
# min    0.000000e+00   -2.900000e+01  -5.900000e+01  1.000000e+00
# 25%    0.000000e+00    4.800000e+01   4.100000e+01  4.800000e+01
# 50%    1.620000e-01    6.100000e+01   5.700000e+01  6.700000e+01
# 75%    5.850000e-01    7.340000e+01   7.100000e+01  8.400000e+01
# max    1.551860e+02    1.706000e+02   1.130000e+02  1.000000e+02
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  1.370980e+06    1.370980e+06     1.370980e+06      976579.000000
# mean   2.952813e+01    9.145091e+00     7.631396e+00           0.007644
# std    1.030335e+00    2.795097e+00     5.600232e+00           0.100136
# min    2.000000e-02    0.000000e+00     0.000000e+00           0.000000
# 25%    2.940000e+01    1.000000e+01     4.600000e+00           0.000000
# 50%    2.986000e+01    1.000000e+01     7.000000e+00           0.000000
# 75%    3.003000e+01    1.000000e+01     1.040000e+01           0.000000
# max    5.804000e+01    1.110000e+02     9.840000e+02          24.000000

# %% [markdown]
# <h3><font color = "green">Data Preprocessing</font></h3>

# %% [markdown]
# The data will pass through the following processes and transformations:
# <br></br>
# * Lists of numerical boolean, and categorical (>2 categories) features.
# * Convert boolean objects to numerical values 0 and 1.
# * Convert Start_Time and End_Time to timestamps using pd.to_datetime.
# * Add additional columns for starting hour, day_of_week, month and year, date.
# * Add an additional column named "Count" equal to 1, for analysis reasons.

# %%
# Numerical, boolean and categorical lists of features
bol_cols = [col for col in accidents_df.columns if accidents_df[col].dtype == object and accidents_df[col].nunique() == 2]
cat_cols = [col for col in accidents_df.columns if accidents_df[col].dtype == object and accidents_df[col].nunique() > 2]
num_cols = [col for col in accidents_df.columns if accidents_df[col].dtype != object]

# %%
### Convert boolean objects to numerical values.

## We will change the 4 features with same categories ("Day", "Night") together and the feature "Side" seperately.

# Convert "Sunrise_Sunset", "Civil_Twilight", "Nautical_Twilight", and "Astronomical_Twilight" features
accidents_df[bol_cols[1:]] = accidents_df[bol_cols[1:]].replace({"Day": 1, "Night": 0})

# Convert "Side" feature
accidents_df["Side"] = accidents_df["Side"].replace({"R": 1, "L": 0})

# Check the changes
accidents_df[bol_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370980 entries, 0 to 1370979
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Side                   1370980 non-null  int64
#  1   Sunrise_Sunset         1370980 non-null  int64
#  2   Civil_Twilight         1370980 non-null  int64
#  3   Nautical_Twilight      1370980 non-null  int64
#  4   Astronomical_Twilight  1370980 non-null  int64
# dtypes: int64(5)
# memory usage: 52.3 MB

# %%
# Convert Star_Time to timestamps
accidents_df[["Start_Time", "End_Time"]] = accidents_df[["Start_Time", "End_Time"]].apply(pd.to_datetime)

# Add columns for starting hour, day of week, month and year
accidents_df["Start_Day_Week"] = accidents_df["Start_Time"].dt.dayofweek
accidents_df["Start_Month"] = accidents_df["Start_Time"].dt.month
accidents_df["Start_Date"] = accidents_df["Start_Time"].dt.date
accidents_df["Start_Hour"] = accidents_df["Start_Time"].dt.hour
accidents_df["Start_Year"] = accidents_df["Start_Time"].dt.year

# Add the column "Count"
accidents_df["Count"] = 1

# %%
accidents_df.head()
# Out:
#           ID  Severity          Start_Time            End_Time  Start_Lat  \
# 0  A-2716600         3 2016-02-08 00:37:08 2016-02-08 06:37:08  40.108910
# 1  A-2716605         3 2016-02-08 07:53:43 2016-02-08 13:53:43  39.172393
# 2  A-2716606         2 2016-02-08 08:16:57 2016-02-08 14:16:57  39.063240
# 3  A-2716607         2 2016-02-08 08:16:57 2016-02-08 14:16:57  39.067080
# 4  A-2716608         2 2016-02-08 08:15:41 2016-02-08 14:15:41  39.775650
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)           Street  Side  \
# 0 -83.092860  40.112060 -83.031870         3.230      Outerbelt E     1
# 1 -84.492792  39.170476 -84.501798         0.500           I-75 S     1
# 2 -84.032430  39.067310 -84.058510         1.427   State Route 32     1
# 3 -84.058550  39.063020 -84.032540         1.423   State Route 32     1
# 4 -84.186030  39.772750 -84.188050         0.227           I-75 S     1
#
#            City      County State Zipcode    Timezone Airport_Code  \
# 0        Dublin    Franklin    OH   43017  US/Eastern         KOSU
# 1    Cincinnati    Hamilton    OH   45217  US/Eastern         KLUK
# 2  Williamsburg    Clermont    OH   45176  US/Eastern         KI69
# 3       Batavia    Clermont    OH   45103  US/Eastern         KI69
# 4        Dayton  Montgomery    OH   45404  US/Eastern         KFFO
#
#      Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 0  2016-02-08 00:53:00            42.1           36.1         58.0
# 1  2016-02-08 07:53:00            37.0           29.8         93.0
# 2  2016-02-08 08:16:00            35.6           29.2        100.0
# 3  2016-02-08 08:16:00            35.6           29.2        100.0
# 4  2016-02-08 08:18:00            33.8            NaN        100.0
#
#    Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 0         29.76            10.0             SW             10.4
# 1         29.69            10.0            WSW             10.4
# 2         29.66            10.0            WSW              8.1
# 3         29.66            10.0            WSW              8.1
# 4         29.63             3.0             SW              2.3
#
#    Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  Give_Way  \
# 0               0.00        Light Rain    False  False     False     False
# 1               0.01        Light Rain    False  False     False     False
# 2                NaN          Overcast    False  False     False     False
# 3                NaN          Overcast    False  False     False     False
# 4                NaN     Mostly Cloudy    False  False     False     False
#
#    Junction  No_Exit  Railway  Roundabout  Station   Stop  Traffic_Calming  \
# 0     False    False    False       False    False  False            False
# 1     False    False    False       False    False  False            False
# 2     False    False    False       False    False  False            False
# 3     False    False    False       False    False  False            False
# 4     False    False    False       False    False  False            False
#
#    Traffic_Signal  Turning_Loop  Sunrise_Sunset  Civil_Twilight  \
# 0           False         False               0               0
# 1           False         False               1               1
# 2            True         False               1               1
# 3           False         False               1               1
# 4           False         False               1               1
#
#    Nautical_Twilight  Astronomical_Twilight  Start_Day_Week  Start_Month  \
# 0                  0                      0               0            2
# 1                  1                      1               0            2
# 2                  1                      1               0            2
# 3                  1                      1               0            2
# 4                  1                      1               0            2
#
#    Start_Date  Start_Hour  Start_Year  Count
# 0  2016-02-08           0        2016      1
# 1  2016-02-08           7        2016      1
# 2  2016-02-08           8        2016      1
# 3  2016-02-08           8        2016      1
# 4  2016-02-08           8        2016      1

# %%
# Save the preproced dataset
accidents_df.to_csv("accidents_df_preproced.csv", index=False)
